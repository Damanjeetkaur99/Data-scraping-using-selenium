# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd
from csv import DictWriter
import openpyxl
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import re
import os
import selenium
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')


driver = webdriver.Chrome(executable_path="/Users/apple/Downloads/chromedriver_mac/chromedriver")
url="http://103.8.249.227:8080/voterlist/"
driver.get(url)
driver.maximize_window()
sleep(5)


dist = '//*[@id="LstDist"]'
driver.find_element(by=By.XPATH, value=(dist)).click()
sleep(2)
dist_counts = len(driver.find_elements(By.XPATH, '//*[@id="LstDist"]/option'))
print("dist", dist_counts)

for i in range(2,dist_counts):
    driver.find_element(by=By.XPATH, value=(dist +'/option['+str(i)+']')).click()
    sleep(2)
    
    lac = '//*[@id="LstLAC"]'
    driver.find_element(by=By.XPATH, value=(lac)).click()
    sleep(2)
    lac_counts = len(driver.find_elements(By.XPATH, '//*[@id="LstLAC"]/option'))
    print("LAC", lac_counts)

    for j in range(2,lac_counts):
        driver.find_element(by=By.XPATH, value=(lac + '/option[' + str(j) + ']')).click()
        sleep(1)
        
        
        ps = '//*[@id="LstPolls"]'
        driver.find_element(by=By.XPATH, value=(ps)).click()
        sleep(1)
        ps_counts = len(driver.find_elements(By.XPATH, '//*[@id="LstPolls"]/option'))
        print("ps", ps_counts)
        df = pd.DataFrame()
        
        for k in range(2,ps_counts):
            driver.find_element(by=By.XPATH, value=(ps + '/option[' + str(k) + ']')).click()
            sleep(1)
            
            mother_roll='//*[@id="LstType"]'
            driver.find_element(by=By.XPATH, value=(mother_roll)).click()
            sleep(1)
            mo_counts=len(driver.find_elements(By.XPATH, '//*[@id="LstType"]/option'))
            print('mother_roll',mo_counts)
            
            for w in range(1,2):
                driver.find_element(by=By.XPATH, value=(mother_roll + '/option[' + str(w) + ']')).click()
                sleep(5)

                driver.find_element(by=By.XPATH, value=('//*[@id="submit"]')).click()
                sleep(2)
                
                
                    
#                     for n in range(1,27):
#                         driver.find_element(by=By.XPATH, value=('//*[@id="tbl_data_next"]')).click()  
#                         sleep(1)
#                 
#                         driver.find_element(by=By.XPATH, value=('//*[@id="tbl_data_length"]/label/select/option[4]')).click()
#                         sleep(1)
#                     
#                         row=driver.find_elements(by=By.XPATH, value=('//*[@id="tbl_data"]/tbody/tr'))
#                         print(len(row))
#                         
#                                       
#                         Voter_no = driver.find_elements(by=By.XPATH, value=('//*[@id="tbl_data"]/tbody/tr/td[2]'))
#                         Name_of_voter = driver.find_elements(by=By.XPATH, value=('//*[@id="tbl_data"]/tbody/tr/td[3]'))
#                         Age = driver.find_elements(by=By.XPATH, value=('//*[@id="tbl_data"]/tbody/tr/td[4]'))
#                         Gender = driver.find_elements(by=By.XPATH, value=('//*[@id="tbl_data"]/tbody/tr/td[5]'))
#                         Name_of_spouse = driver.find_elements(by=By.XPATH, value=('//*[@id="tbl_data"]/tbody/tr/td[6]'))
#                         Mothers_Fathers_name = driver.find_elements(by=By.XPATH, value=('//*[@id="tbl_data"]/tbody/tr/td[7]'))
#                         sleep(2)
#                         result = []
#                         
#                         for r in range(len(row)):
#                             data = {'voter_no':Voter_no[r].text,
#                                     'name_of_voter':Name_of_voter[r].text,
#                                     'age':Age[r].text,
#                                     'gender':Gender[r].text,
#                                     'Name_of_spouse':Name_of_spouse[r].text,
#                                     'Mothers_Fathers_name':Mothers_Fathers_name[r].text}
#                             result.append(data)
#                         sleep(1)
#                         df_data = pd.DataFrame(result)
#                         df=df.append(df_data)
#                         print(df)
#                 df.to_excel('Nepal_election_results.xlsx')                    
#
# Out:
# dist 35
# LAC 3
# ps 205
# mother_roll 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mz/0srknmjj1qnbm90_bhr1dfyr0000gn/T/ipykernel_3238/2479999417.py in <module>
#      71
#      72
# ---> 73                 Captcha.browser.find_element_by_link_text("Delete User").click()
#      74                 alert = world.browser.switch_to.alert
#      75                 alert.accept()
#
# NameError: name 'Captcha' is not defined
